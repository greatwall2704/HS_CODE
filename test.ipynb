# %%
import os
import pandas as pd
from typing import List, Dict, Any

# %%
df_original = pd.read_csv("evaluation/LLM-as-a-Judge/results/evaluation_results.csv", dtype=str)
df = df_original.head(19)
df
# Out:
#         mahs giu_dung_noi_dung dung_chuyen_nganh phan_biet_ma_hs  \
# 0   01012900              True              True            True
# 1   01013010              True              True            True
# 2   01013090              True              True            True
# 3   01019000              True              True            True
# 4   01022100              True              True            True
# 5   01022911              True              True            True
# 6   01022919              True              True            True
# 7   01022990              True              True            True
# 8   01023100              True              True            True
# 9   01023900              True              True            True
# 10  01029010              True              True            True
# 11  01029090              True              True            True
# 12  01031000              True              True            True
# ...

# %%
df_new = pd.read_csv("data/description data/data_with_new_mota.csv", dtype=str)
df
# Out:
#    Unnamed: 0      mahs                                              mo_ta
# 0           1  01012900           Ngựa, lừa, la sống/- Ngựa:/- - Loại khác
# 1           2  01013010  Ngựa, lừa, la sống/- Lừa:/- - Loại thuần chủng...
# 2           3  01013090            Ngựa, lừa, la sống/- Lừa:/- - Loại khác
# 3           4  01019000                     Ngựa, lừa, la sống/- Loại khác
# 4           5  01022100  Động vật sống họ trâu bò/- Gia súc:/- - Loại t...
# 5           6  01022911  Động vật sống họ trâu bò/- Gia súc:/- - Loại k...
# 6           7  01022919  Động vật sống họ trâu bò/- Gia súc:/- - Loại k...
# 7           8  01022990  Động vật sống họ trâu bò/- Gia súc:/- - Loại k...
# 8           9  01023100  Động vật sống họ trâu bò/- Trâu:/- - Loại thuầ...
# 9          10  01023900     Động vật sống họ trâu bò/- Trâu:/- - Loại khác
# 10         11  01029010  Động vật sống họ trâu bò/- Loại khác:/- - Loại...
# ...

# %%
df['mo_ta_moi'] = df_new['mo_ta'].values
# Out:
# /tmp/ipykernel_2986169/3876896610.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['mo_ta_moi'] = df_new['mo_ta'].values

# %%
df
# Out:
#    Unnamed: 0      mahs                                              mo_ta  \
# 0           1  01012900           Ngựa, lừa, la sống/- Ngựa:/- - Loại khác
# 1           2  01013010  Ngựa, lừa, la sống/- Lừa:/- - Loại thuần chủng...
# 2           3  01013090            Ngựa, lừa, la sống/- Lừa:/- - Loại khác
# 3           4  01019000                     Ngựa, lừa, la sống/- Loại khác
# 4           5  01022100  Động vật sống họ trâu bò/- Gia súc:/- - Loại t...
# 5           6  01022911  Động vật sống họ trâu bò/- Gia súc:/- - Loại k...
# 6           7  01022919  Động vật sống họ trâu bò/- Gia súc:/- - Loại k...
# 7           8  01022990  Động vật sống họ trâu bò/- Gia súc:/- - Loại k...
# 8           9  01023100  Động vật sống họ trâu bò/- Trâu:/- - Loại thuầ...
# 9          10  01023900     Động vật sống họ trâu bò/- Trâu:/- - Loại khác
# 10         11  01029010  Động vật sống họ trâu bò/- Loại khác:/- - Loại...
# ...

# %%
df = df.loc[:, ~df.columns.str.contains('^Unnamed')]

# %%
# ...existing code...
df.to_csv("data/description data/mota_motamoi.csv", index=False)
# ...existing code...

# %%
df
# Out:
#         mahs                                              mo_ta  \
# 0   01012900           Ngựa, lừa, la sống/- Ngựa:/- - Loại khác
# 1   01013010  Ngựa, lừa, la sống/- Lừa:/- - Loại thuần chủng...
# 2   01013090            Ngựa, lừa, la sống/- Lừa:/- - Loại khác
# 3   01019000                     Ngựa, lừa, la sống/- Loại khác
# 4   01022100  Động vật sống họ trâu bò/- Gia súc:/- - Loại t...
# 5   01022911  Động vật sống họ trâu bò/- Gia súc:/- - Loại k...
# 6   01022919  Động vật sống họ trâu bò/- Gia súc:/- - Loại k...
# 7   01022990  Động vật sống họ trâu bò/- Gia súc:/- - Loại k...
# 8   01023100  Động vật sống họ trâu bò/- Trâu:/- - Loại thuầ...
# 9   01023900     Động vật sống họ trâu bò/- Trâu:/- - Loại khác
# 10  01029010  Động vật sống họ trâu bò/- Loại khác:/- - Loại...
# 11  01029090  Động vật sống họ trâu bò/- Loại khác:/- - Loại...
# 12  01031000          Lợn sống/- Loại thuần chủng để nhân giống
# 13  01039100    Lợn sống/- Loại khác:/- - Khối lượng dưới 50 kg
# ...
